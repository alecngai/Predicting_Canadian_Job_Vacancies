# %%
# Importing Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine, func
from sqlalchemy import inspect

import pandas as pd

import psycopg2
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# Establish a connection to the database
conn = psycopg2.connect(
    host = "group3db.cueberfdee85.us-east-2.rds.amazonaws.com", 
    port = 5432, 
    dbname = "sample_db", 
    user = "postgres", 
    password = "databootcampcapstone")

print("Postgres Connected")
# Out:
# Postgres Connected

# %%
# Establishing a cursur
cur = conn.cursor()

# %%
cur.execute("""SELECT * FROM vacancies""")
query_results = cur.fetchall()
print(query_results)
# Out:
# [('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 430, 'Business, finance and administration occupations ', 1, 2015, 2, 36393), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 170, 'Natural and applied sciences and related occupations ', 2, 2015, 2, 36978), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 265, 'Health occupations ', 3, 2015, 2, 37196), ('2015-04', 'Newfoundland and Labrador', 'Part-time', 'Job vacancies', 260, 'Health occupations ', 3, 2015, 2, 37199), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 130, 'Occupations in education, law and social, community and government services ', 4, 2015, 2, 37788), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 955, 'Sales and service occupations ', 6, 2015, 2, 38098), ('2015-04', 'Newfoundland and Labrador', 'Part-time', 'Job vacancies', 945, 'Sales and service occupations ', 6, 2015, 2, 38101), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 735, 'Trades, transport and equipment operators and related occupations ', 7, 2015, 2, 39115), ('2015-04', 'Newfoundland and Labrador', 'Full-time', 'Job vacancies', 305, 'Occupations in manufacturing and utilities ', 9, 2015, 2, 39820), ('2015-04', 'Prince Edward Island', 'Full-time', 'Job vacancies', 70, 'Natural and applied sciences and related occupations ', 2, 2015, 2, 40126), ('2015-04', 'Prince Edward Island', 'Full-time', 'Job vacancies', 440, 'Sales and service occupations ', 6, 2015, 2, 40537), ('2015-04', 'Prince Edward Island', 'Part-time', 'Job vacancies', 425, 'Sales and service occupations ', 6, 2015, 2, 40540), ('2015-04', 'Prince Edward Island', 'Full-time', 'Job vacancies', 100, 'Occupations in manufacturing and utilities ', 9, 2015, 2, 41175), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 375, 'Management occupations ', 0, 2015, 2, 41402), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 770, 'Business, finance and administration occupations ', 1, 2015, 2, 42007), ('2015-04', 'Nova Scotia', 'Part-time', 'Job vacancies', 185, 'Business, finance and administration occupations ', 1, 2015, 2, 42010), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 495, 'Natural and applied sciences and related occupations ', 2, 2015, 2, 42750), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 405, 'Health occupations ', 3, 2015, 2, 43074), ('2015-04', 'Nova Scotia', 'Part-time', 'Job vacancies', 520, 'Health occupations ', 3, 2015, 2, 43077), ('2015-04', 'Nova Scotia', 'Part-time', 'Job vacancies', 150, 'Occupations in education, law and social, community and government services ', 4, 2015, 2, 43934), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 240, 'Occupations in art, culture, recreation and sport ', 5, 2015, 2, 44321), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 2145, 'Sales and service occupations ', 6, 2015, 2, 44546), ('2015-04', 'Nova Scotia', 'Part-time', 'Job vacancies', 1980, 'Sales and service occupations ', 6, 2015, 2, 44549), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 1650, 'Trades, transport and equipment operators and related occupations ', 7, 2015, 2, 46044), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 445, 'Natural resources, agriculture and related production occupations ', 8, 2015, 2, 46842), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 460, 'Occupations in manufacturing and utilities ', 9, 2015, 2, 47056), ('2015-04', 'Nova Scotia', 'Full-time', 'Job vacancies', 285, 'Unclassified occupations', None, 2015, 2, 47601), ('2015-04', 'New Brunswick', 'Full-time', 'Job vacancies', 550, 'Business, finance and administration occupations ', 1, 2015, 2, 48112), ('2015-04', 'New Brunswick', 'Full-time', 'Job vacancies', 220, 'Health occupations ', 3, 2015, 2, 49157), ('2015-04', 'New Brunswick', 'Part-time', 'Job vacancies', 415, 'Health occupations ', 3, 2015, 2, 49160), ('2015-04', 'New Brun ...

# %%
column_names = ("REF_DATE",	"Location",	"JobDetails",	"Statistics",	"VALUE",	"NOC_Desc",	"NOC_Code",	"Year",	"Quarter",	"ID")
df = pd.DataFrame(query_results, columns=column_names)
df.head()
# Out:
#   REF_DATE                   Location JobDetails  ...  Year  Quarter     ID
# 0  2015-04  Newfoundland and Labrador  Full-time  ...  2015        2  36393
# 1  2015-04  Newfoundland and Labrador  Full-time  ...  2015        2  36978
# 2  2015-04  Newfoundland and Labrador  Full-time  ...  2015        2  37196
# 3  2015-04  Newfoundland and Labrador  Part-time  ...  2015        2  37199
# 4  2015-04  Newfoundland and Labrador  Full-time  ...  2015        2  37788
#
# [5 rows x 10 columns]

# %%
# Close the cursor and connection
cur.close()
conn.close()
print("Connection Closed")
# Out:
# Connection Closed
