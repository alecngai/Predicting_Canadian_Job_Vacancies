# %%
import pandas as pd

# %%
df = pd.read_csv("14100328.csv")
df.head(20)
# Out:
# C:\Users\Alec\Downloads\Anaconda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    REF_DATE     GEO           DGUID National Occupational Classification  \
# 0   2015-01  Canada  2016A000011124               Total, all occupations
# 1   2015-01  Canada  2016A000011124               Total, all occupations
# 2   2015-01  Canada  2016A000011124               Total, all occupations
# 3   2015-01  Canada  2016A000011124               Total, all occupations
# 4   2015-01  Canada  2016A000011124               Total, all occupations
# 5   2015-01  Canada  2016A000011124               Total, all occupations
# 6   2015-01  Canada  2016A000011124               Total, all occupations
# 7   2015-01  Canada  2016A000011124               Total, all occupations
# ...

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'National Occupational Classification',
#        'Job vacancy characteristics', 'Statistics', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df = df[["REF_DATE", "GEO", "National Occupational Classification", "Job vacancy characteristics", "Statistics", "UOM", "VALUE"]]
df.head()
# Out:
#   REF_DATE     GEO National Occupational Classification  \
# 0  2015-01  Canada               Total, all occupations
# 1  2015-01  Canada               Total, all occupations
# 2  2015-01  Canada               Total, all occupations
# 3  2015-01  Canada               Total, all occupations
# 4  2015-01  Canada               Total, all occupations
#
#   Job vacancy characteristics                   Statistics         UOM  \
# 0     Type of work, all types                Job vacancies      Number
# 1     Type of work, all types  Proportion of job vacancies  Percentage
# 2     Type of work, all types  Average offered hourly wage     Dollars
# 3                   Full-time                Job vacancies      Number
# 4                   Full-time  Proportion of job vacancies  Percentage
#
#        VALUE
# 0  408125.00
# 1     100.00
# 2      19.15
# 3  303685.00
# 4      74.40

# %%
df.to_csv("14100328_Dropped_Columns.csv")

# %%
df["National Occupational Classification"].value_counts()
# Out:
# Total, all occupations                                                              39816
# Service supervisors and specialized service occupations [63]                        39816
# Chefs and cooks [632]                                                               39816
# Cooks [6322]                                                                        39816
# Transport and heavy equipment operation and related maintenance occupations [75]    39816
#                                                                                     ...
# Other personal service occupations [6564]                                           38976
# Judges [4111]                                                                       38948
# Non-commissioned ranks of the Canadian Armed Forces [4313]                          38948
# Commissioned officers of the Canadian Armed Forces [0433]                           38934
# ...
